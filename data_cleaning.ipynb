# %%
import pandas as pd

# %%
reaction=pd.read_csv('https://raw.githubusercontent.com/campusx-official/data-wrangling/master/adverse_reactions.csv')
patients=pd.read_csv('https://raw.githubusercontent.com/campusx-official/data-wrangling/master/patients.csv')
treatment=pd.read_csv('https://raw.githubusercontent.com/campusx-official/data-wrangling/master/treatments.csv')
treatments=pd.read_csv('https://raw.githubusercontent.com/campusx-official/data-wrangling/master/treatments_cut.csv')

# %%
with pd.ExcelWriter('clinical_trail.xlsx') as writer:
  patients.to_excel(writer , sheet_name='patients')
  reaction.to_excel(writer , sheet_name='reaction')
  treatment.to_excel(writer , sheet_name='treatment')
  treatments.to_excel(writer , sheet_name='treatments')

# %% [markdown]
# #`issue with dataset`
# 1.`dirty data`
#
#   table -'patients'
# - patient_id=9 , name is incorrect 'dsvid' instead of david. `accuracy issue`
# - state column have irregularities both name and abbrivations.`consistency`
# - zip_code column has entiry with four digit.`validity issue`
# - data missing for 12 patients address ,city and zipcode.`completion issue`
# - incorrect data type assinged to birth_date,zip_code and assigned_sex columns.`validity issue`
# - dupicate entry in given_name and surname columns.`accuracy`
# - one wroung data in weight  where weight == 48lbs.`accuracy`
# - one  wroung data in height where height is 27inch.`accuracy`
#
#
#   table-'treatment' and 'treatnets'
# - firstname and sirname is in lower case.`consistency`
# - 'u' should be deprecated from auralin and nevodra column.`validity issue`
# - in auralin and nevodra column replace hash with nan.`validity issue`
# - missing values in hba1c_change column. `completion issue`
# - one duplicate entry by joseph day.`accuracy`
# - wroung entrys in hba1c_change column.`accuracy`
# - `merge both table to one.`
#
#
#
#   table-'reaction'
# - given_name and sirname is in lower case.`consistency`
#
# 2.`messy data`
#
#  table -'patients'
# - phone and email in one column
#
#
#  table -'treatment' and 'treatments'
# - auralin and nevodra should be divide into two columns one be start and second br end dose.
#
#
# table -'reaction'
# - this table sholud not exist independently
#
#
# #order of severity
# > `completeness>valididty>accuracy>consistency`
#
# - check- `you should handle messy data after hamdeling completeness issue.`

# %%
patients.head()
# Out:
#    patient_id assigned_sex given_name  surname                    address  \
# 0           1       female        Zoe  Wellish       576 Brown Bear Drive
# 1           2       female     Pamela     Hill  2370 University Hill Road
# 2           3         male        Jae   Debord      1493 Poling Farm Road
# 3           4         male       Liêm     Phan        2335 Webster Street
# 4           5         male        Tim  Neudorf       1428 Turkey Pen Lane
#
#                 city       state  zip_code        country  \
# 0  Rancho California  California   92390.0  United States
# 1          Armstrong    Illinois   61812.0  United States
# 2               York    Nebraska   68467.0  United States
# 3         Woodbridge          NJ    7095.0  United States
# 4             Dothan          AL   36303.0  United States
#
#                                       contact  birthdate  weight  height   bmi
# 0        951-719-9170ZoeWellish@superrito.com  7/10/1976   121.7      66  19.6
# ...

# %%
patients.tail()
# Out:
#      patient_id assigned_sex given_name      surname  \
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                       address           city     state  zip_code  \
# 498       2530 Victoria Court   Milton Mills        ME    3852.0
# 499  494 Clarksburg Park Road         Sedona        AZ   86341.0
# 500         649 Nutter Street  Overland Park        MO   64110.0
# 501  3652 Boone Crockett Lane        Seattle        WA   98109.0
# 502         2778 North Avenue           Burr  Nebraska   68324.0
#
#            country                                          contact  \
# 498  United States      207-477-0579MustafaLindstrom@jourrapide.com
# 499  United States               928-284-4492RumanBisliev@gustr.com
# ...

# %%
patients.sample(10)
# Out:
#      patient_id assigned_sex given_name   surname  \
# 497         498         male   Masataka  Murakami
# 24           25         male      Jakob  Jakobsen
# 90           91         male       Ingo    Rokavc
# 267         268       female   Bernarda   Cindrić
# 178         179       female       Else  Andersen
# 294         295       female      Annie     Allen
# 326         327       female      Suoma  Koivunen
# 31           32         male      Tomáš  Navrátil
# 346         347       female      Helen     Luwam
# 119         120       female      Chaja      Bouw
#
#                           address         city     state  zip_code  \
# 497              1179 Patton Lane        Tulsa        OK   74116.0
# 24              648 Old Dear Lane  Port Jervis  New York   12771.0
# 90        4271 Cherry Ridge Drive      Buffalo  New York   14214.0
# 267           1753 Sherman Street       Salina        KS   67401.0
# 178           1386 Farland Street      Chicago  Illinois   60631.0
# ...

# %%
reaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   given_name        34 non-null     object
#  1   surname           34 non-null     object
#  2   adverse_reaction  34 non-null     object
# dtypes: object(3)
# memory usage: 944.0+ bytes

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
patients[patients['address'].isnull()]
# Out:
#      patient_id assigned_sex given_name      surname address city state  \
# 209         210       female     Lalita  Eldarkhanov     NaN  NaN   NaN
# 219         220         male         Mỹ        Quynh     NaN  NaN   NaN
# 230         231       female  Elisabeth      Knudsen     NaN  NaN   NaN
# 234         235       female    Martina    Tománková     NaN  NaN   NaN
# 242         243         male       John      O'Brian     NaN  NaN   NaN
# 249         250         male   Benjamin       Mehler     NaN  NaN   NaN
# 257         258         male        Jin         Kung     NaN  NaN   NaN
# 264         265       female   Wafiyyah       Asfour     NaN  NaN   NaN
# 269         270       female     Flavia   Fiorentino     NaN  NaN   NaN
# 278         279       female   Generosa        Cabán     NaN  NaN   NaN
# 286         287         male      Lewis         Webb     NaN  NaN   NaN
# 296         297       female        Chỉ          Lâm     NaN  NaN   NaN
#
# ...

# %%
patients.isnull().sum()
# Out:
# patient_id       0
# assigned_sex     0
# given_name       0
# surname          0
# address         12
# city            12
# state           12
# zip_code        12
# country         12
# contact         12
# birthdate        0
# weight           0
# height           0
# bmi              0
# dtype: int64

# %%
patients['patient_id'].duplicated().sum()
# Out:
# 0

# %%
patients[patients.duplicated(subset=['given_name','surname'])]
# Out:
#      patient_id assigned_sex given_name surname          address      city  \
# 229         230         male       John     Doe  123 Main Street  New York
# 237         238         male       John     Doe  123 Main Street  New York
# 244         245         male       John     Doe  123 Main Street  New York
# 251         252         male       John     Doe  123 Main Street  New York
# 277         278         male       John     Doe  123 Main Street  New York
#
#     state  zip_code        country                      contact birthdate  \
# 229    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 237    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 244    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 251    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
# 277    NY   12345.0  United States  johndoe@email.com1234567890  1/1/1975
#
#      weight  height   bmi
# 229   180.0      72  24.4
# ...

# %%
treatment[treatment.duplicated()]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatment[treatment.duplicated(subset=['given_name','surname'])]
# Out:
#     given_name surname    auralin novodra  hba1c_start  hba1c_end  \
# 136     joseph     day  29u - 36u       -          7.7       7.19
#
#      hba1c_change
# 136           NaN

# %%
treatments[treatments.duplicated(subset=['given_name','surname'])]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, auralin, novodra, hba1c_start, hba1c_end, hba1c_change]
# Index: []

# %%
reaction[reaction.duplicated()]
# Out:
# Empty DataFrame
# Columns: [given_name, surname, adverse_reaction]
# Index: []

# %%
patients.describe()
# Out:
#        patient_id      zip_code      weight      height         bmi
# count  503.000000    491.000000  503.000000  503.000000  503.000000
# mean   252.000000  49084.118126  173.434990   66.634195   27.483897
# std    145.347859  30265.807442   33.916741    4.411297    5.276438
# min      1.000000   1002.000000   48.800000   27.000000   17.100000
# 25%    126.500000  21920.500000  149.300000   63.000000   23.300000
# 50%    252.000000  48057.000000  175.300000   67.000000   27.200000
# 75%    377.500000  75679.000000  199.500000   70.000000   31.750000
# max    503.000000  99701.000000  255.900000   79.000000   37.700000

# %%
treatment.sort_values('hba1c_start').tail()
# Out:
#     given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 25      benoît     bonami          -  44u - 43u         9.82       9.40
# 171    justyna  kowalczyk  24u - 34u          -         9.84       9.44
# 81      robert     wagner  43u - 49u          -         9.84       9.52
# 75   mackenzie      mckay          -  44u - 43u         9.87       9.48
# 166      annie      allen  36u - 42u          -         9.95       9.58
#
#      hba1c_change
# 25           0.92
# 171           NaN
# 81           0.32
# 75           0.39
# 166          0.37

# %% [markdown]
# #`make a copy of youe dat frame before you start data cleaning.`

# %%
patients_df=patients.copy()
treatment_df=treatment.copy()
treatments_df=treatments.copy()
reaction_df=reaction.copy()

# %% [markdown]
# #`define`
# - `replace all missing values of patients with no data.`
# -`substract hba1c_start from  hba1c_end to fill up missing values in  hbaic_change.`
# - `in patients we use regex to seperate email and phone to separe columns.`
# - `merge auralin and nevodra to one column and also treatment and treatments and seperate 'u`.
# -`add reaction dataset to patients dataset.`
# -`correct the zipcode format`
# -`put name david in where  patient_id=9`
# -`delete all the duplicate entry in patients dataset`
# -`change wroung weight value for patients_id=211`
# -`change wroung height value for patients_id=5`
# -`delete duplicate entry in treatment dataset`
# -`set irregularities in statw e column in patients`
# -`make treatment dataset  column given_name and surname in lower case.`

# %%
#CODE
patients_df.fillna('no data',inplace=True)

# %%
#TEST
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503 entries, 0 to 502
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   patient_id    503 non-null    int64
#  1   assigned_sex  503 non-null    object
#  2   given_name    503 non-null    object
#  3   surname       503 non-null    object
#  4   address       503 non-null    object
#  5   city          503 non-null    object
#  6   state         503 non-null    object
#  7   zip_code      503 non-null    object
#  8   country       503 non-null    object
#  9   contact       503 non-null    object
#  10  birthdate     503 non-null    object
#  11  weight        503 non-null    float64
#  12  height        503 non-null    int64
#  13  bmi           503 non-null    float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 55.1+ KB

# %%
#TEST
treatment_df.head()
# Out:
#   given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0   veronika    jindrová  41u - 48u          -         7.63       7.20
# 1     elliot  richardson          -  40u - 45u         7.56       7.09
# 2   yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3       skye  gormanston  33u - 36u          -         7.97       7.62
# 4     alissa      montez          -  33u - 29u         7.78       7.46
#
#    hba1c_change
# 0           NaN
# 1          0.97
# 2           NaN
# 3          0.35
# 4          0.32

# %%
#TEST
treatments_df.head()
# Out:
#   given_name    surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0      jožka  resanovič  22u - 30u          -         7.56       7.22
# 1  inunnguaq   heilmann  57u - 67u          -         7.85       7.45
# 2      alwin   svensson  36u - 39u          -         7.78       7.34
# 3        thể      lương          -  61u - 64u         7.64       7.22
# 4     amanda    ribeiro  36u - 44u          -         7.85       7.47
#
#    hba1c_change
# 0          0.34
# 1           NaN
# 2           NaN
# 3          0.92
# 4          0.38

# %%
#CODE
treatment_df['hba1c_change']=treatment_df['hba1c_start']-treatment_df['hba1c_end']
treatments_df['hba1c_change']=treatments_df['hba1c_start']-treatments_df['hba1c_end']

# %%
#CODE
import numpy as np
import re

def find_contact_details(text: str) -> tuple:
    # it the value is NaN, then return it
    if pd.isna(text):
        return np.nan

    # create the phone number pattern
    phone_number_pattern = re.compile(r"(\+[\d]{1,3}\s)?(\(?[\d]{3}\)?\s?-?[\d]{3}\s?-?[\d]{4})")
    # find the phone number from the value/text, as a result we will get a list
    phone_number  = re.findall(phone_number_pattern, text)

    # if length is 0, then the regex can't find any ph number, then define with NaN
    if len(phone_number) <= 0:



        phone_number = np.nan
    # if the country code is attached with the ph number, for that case, the first
    # element will be the country code and the 2nd element will be the actual ph
    # number. So, get that ph number
    elif len(phone_number) >= 2:
        phone_number = phone_number[1]
    # else, we will get the ph number. Grab it.
    else:
        phone_number = phone_number[0]

    # if we found the ph number (with/without country code), then remove that part from the actual value.
    # after removing the ph number, the remaining string might be the email address.
    possible_email_add = re.sub(phone_number_pattern, "", text).strip()

    # then return the ph number and the email address
    return phone_number, possible_email_add

# %%
patients_df['phone']=patients_df["contact"].apply(lambda x: find_contact_details(x)).apply(lambda x:x[0])
patients_df['email'] =patients_df["contact"].apply(lambda x: find_contact_details(x)).apply(lambda x:x[1])

# %%
patients_df['contact']=patients_df.drop(columns='contact',inplace=True)

# %%
#TEST
patients_df
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California  92390.0
# 1    2370 University Hill Road          Armstrong    Illinois  61812.0
# 2        1493 Poling Farm Road               York    Nebraska  68467.0
# ...

# %%
#code
treatment_dfs=pd.concat([treatment_df,treatments_df])
#test
treatment_dfs
# Out:
#    given_name     surname    auralin    novodra  hba1c_start  hba1c_end  \
# 0    veronika    jindrová  41u - 48u          -         7.63       7.20
# 1      elliot  richardson          -  40u - 45u         7.56       7.09
# 2    yukitaka    takenaka          -  39u - 36u         7.68       7.25
# 3        skye  gormanston  33u - 36u          -         7.97       7.62
# 4      alissa      montez          -  33u - 29u         7.78       7.46
# ..        ...         ...        ...        ...          ...        ...
# 65     rovzan     kishiev  32u - 37u          -         7.75       7.41
# 66      jakob    jakobsen          -  28u - 26u         7.96       7.51
# 67      bernd   schneider  48u - 56u          -         7.74       7.44
# 68      berta  napolitani          -  42u - 44u         7.68       7.21
# 69     armina       sauvé  36u - 46u          -         7.86       7.40
#
#     hba1c_change
# 0           0.43
# 1           0.47
# 2           0.43
# 3           0.35
# ...

# %%
#code
treatment_dfs=treatment_dfs.melt(id_vars=['given_name','surname','hba1c_start',	'hba1c_end'	,'hba1c_change'],var_name='type',value_name='dousage_range')
#test
treatment_dfs
# Out:
#     given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0     veronika    jindrová         7.63       7.20          0.43  auralin
# 1       elliot  richardson         7.56       7.09          0.47  auralin
# 2     yukitaka    takenaka         7.68       7.25          0.43  auralin
# 3         skye  gormanston         7.97       7.62          0.35  auralin
# 4       alissa      montez         7.78       7.46          0.32  auralin
# ..         ...         ...          ...        ...           ...      ...
# 695     rovzan     kishiev         7.75       7.41          0.34  novodra
# 696      jakob    jakobsen         7.96       7.51          0.45  novodra
# 697      bernd   schneider         7.74       7.44          0.30  novodra
# 698      berta  napolitani         7.68       7.21          0.47  novodra
# 699     armina       sauvé         7.86       7.40          0.46  novodra
#
#     dousage_range
# 0       41u - 48u
# 1               -
# 2               -
# ...

# %%
#code
treatment_dfs=treatment_dfs[treatment_dfs['dousage_range']!='-']
treatment_dfs
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.45  novodra
# 690        maret    sultygov         7.67       7.30          0.37  novodra
# 694        lixue       hsueh         9.21       8.80          0.41  novodra
# 696        jakob    jakobsen         7.96       7.51          0.45  novodra
# 698        berta  napolitani         7.68       7.21          0.47  novodra
#
#     dousage_range
# 0       41u - 48u
# ...

# %%
#code
treatment_dfs.loc[:,'dousage_start'] = treatment_dfs['dousage_range'].str.split('-').str.get(0)
treatment_dfs.loc[:,'dousage_end'] = treatment_dfs['dousage_range'].str.split('-').str.get(1)
# Out:
# <ipython-input-432-e4b5ae4319ee>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_dfs.loc[:,'dousage_start'] = treatment_dfs['dousage_range'].str.split('-').str.get(0)
# <ipython-input-432-e4b5ae4319ee>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_dfs.loc[:,'dousage_end'] = treatment_dfs['dousage_range'].str.split('-').str.get(1)

# %%
#code
treatment_dfs.loc[:,'dousage_start']=treatment_dfs['dousage_start'].str.replace('u','')
treatment_dfs.loc[:,'dousage_end']=treatment_dfs['dousage_end'].str.replace('u','')

# %%
#code
treatment_dfs['dousage_start']=treatment_dfs['dousage_start'].astype('int')
treatment_dfs['dousage_end']=treatment_dfs['dousage_end'].astype('int')
# Out:
# <ipython-input-434-207e9f6d7bb9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_dfs['dousage_start']=treatment_dfs['dousage_start'].astype('int')
# <ipython-input-434-207e9f6d7bb9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_dfs['dousage_end']=treatment_dfs['dousage_end'].astype('int')

# %%
treatment_dfs.drop(columns='dousage_range',inplace=True)
# Out:
# <ipython-input-435-c9a4405a0d36>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   treatment_dfs.drop(columns='dousage_range',inplace=True)

# %%
treatment_dfs
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 3           skye  gormanston         7.97       7.62          0.35  auralin
# 6         sophia      haugen         7.65       7.27          0.38  auralin
# 7          eddie      archer         7.89       7.55          0.34  auralin
# 9           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 688  christopher    woodward         7.51       7.06          0.45  novodra
# 690        maret    sultygov         7.67       7.30          0.37  novodra
# 694        lixue       hsueh         9.21       8.80          0.41  novodra
# 696        jakob    jakobsen         7.96       7.51          0.45  novodra
# 698        berta  napolitani         7.68       7.21          0.47  novodra
#
#      dousage_start  dousage_end
# ...

# %%
#test
treatment_dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 350 entries, 0 to 698
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   given_name     350 non-null    object
#  1   surname        350 non-null    object
#  2   hba1c_start    350 non-null    float64
#  3   hba1c_end      350 non-null    float64
#  4   hba1c_change   350 non-null    float64
#  5   type           350 non-null    object
#  6   dousage_start  350 non-null    int64
#  7   dousage_end    350 non-null    int64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 24.6+ KB

# %%
#code
treatment_dfs=treatment_dfs.merge(reaction_df,how='left',on=['given_name','surname'])
#test
treatment_dfs
# Out:
#       given_name     surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 0       veronika    jindrová         7.63       7.20          0.43  auralin
# 1           skye  gormanston         7.97       7.62          0.35  auralin
# 2         sophia      haugen         7.65       7.27          0.38  auralin
# 3          eddie      archer         7.89       7.55          0.34  auralin
# 4           asia     woźniak         7.76       7.37          0.39  auralin
# ..           ...         ...          ...        ...           ...      ...
# 345  christopher    woodward         7.51       7.06          0.45  novodra
# 346        maret    sultygov         7.67       7.30          0.37  novodra
# 347        lixue       hsueh         9.21       8.80          0.41  novodra
# 348        jakob    jakobsen         7.96       7.51          0.45  novodra
# 349        berta  napolitani         7.68       7.21          0.47  novodra
#
# ...

# %%
#code
patients_df['zip_code'] =patients_df['zip_code'].astype(str).str.extract(r'(\d{5})').fillna('00000').astype(int)

# %%
patients_df['zip_code'] = patients_df['zip_code'].astype(str).str.zfill(5)

# %%
#test
patients_df.head(10)
# Out:
#    patient_id assigned_sex given_name     surname                     address  \
# 0           1       female        Zoe     Wellish        576 Brown Bear Drive
# 1           2       female     Pamela        Hill   2370 University Hill Road
# 2           3         male        Jae      Debord       1493 Poling Farm Road
# 3           4         male       Liêm        Phan         2335 Webster Street
# 4           5         male        Tim     Neudorf        1428 Turkey Pen Lane
# 5           6         male     Rafael       Costa          1140 Willis Avenue
# 6           7       female       Mary       Adams            3145 Sheila Lane
# 7           8       female     Xiuxiu       Chang  2687 Black Oak Hollow Road
# 8           9         male      Dsvid  Gustafsson          1790 Nutter Street
# 9          10       female     Sophie     Cabrera           3303 Anmoore Road
#
#                 city       state zip_code        country   birthdate  weight  \
# ...

# %%
#code
patients_df.loc[patients_df['patient_id']==9,'given_name']=patients_df.loc[patients_df['patient_id']==9,'given_name'].str.replace('Dsvid','David')

# %%
#code

patients_df=patients_df.drop_duplicates(keep='first',subset=['given_name', 'surname'])

# %%
#test
patients_df[patients_df['given_name']=='John']
# Out:
#      patient_id assigned_sex given_name      surname                  address  \
# 140         141         male       John  Teichelmann    631 Isaacs Creek Road
# 153         154         male       John     Carreiro  1463 Martha Ellen Drive
# 215         216         male       John          Doe          123 Main Street
# 242         243         male       John      O'Brian                  no data
#
#          city    state zip_code        country  birthdate  weight  height  \
# 140   Decatur       IL    62522  United States  12/3/1958   214.1      72
# 153      Reno       NV    89509  United States   4/8/1976   177.8      68
# 215  New York       NY    12345  United States   1/1/1975   180.0      72
# 242   no data  no data    00000        no data  2/25/1957   205.3      74
#
#       bmi             phone                         email contact
# 140  29.0  (, 217-421-0935)    JohnTeichelmann@dayrep.com    None
# 153  27.0  (, 775 770 7827)  JohnACarreiro@superrito.com1    None
# ...

# %%
#code
index=patients_df[patients_df['patient_id']==211].index
patients_df.loc[index,'weight']=105

# %%
#test
patients_df[patients_df['patient_id']==211]
# Out:
#      patient_id assigned_sex given_name   surname              address  \
# 210         211       female    Camilla  Zaitseva  4689 Briarhill Lane
#
#         city state zip_code        country   birthdate  weight  height   bmi  \
# 210  Wooster    OH    44691  United States  11/26/1938   105.0      63  19.1
#
#                 phone                          email contact
# 210  (, 330-202-2145)  CamillaZaitseva@superrito.com    None

# %%
#code
index=patients_df[patients_df['patient_id']==5].index
patients_df.loc[index,'height']= 66

# %%
#test
patients_df[patients_df['patient_id']==5]
# Out:
#    patient_id assigned_sex given_name  surname               address    city  \
# 4           5         male        Tim  Neudorf  1428 Turkey Pen Lane  Dothan
#
#   state zip_code        country  birthdate  weight  height   bmi  \
# 4    AL    36303  United States  2/18/1928   192.3      66  26.1
#
#               phone                email contact
# 4  (, 334-515-7487)  TimNeudorf@cuvox.de    None

# %%
treatment_dfs[treatment_dfs['given_name']=='joseph']
#test
# Out:
#     given_name surname  hba1c_start  hba1c_end  hba1c_change     type  \
# 5       joseph     day         7.70       7.19          0.51  auralin
# 62      joseph     day         7.70       7.19          0.51  auralin
# 167     joseph  tucker         7.67       7.30          0.37  auralin
#
#      dousage_start  dousage_end adverse_reaction
# 5               29           36     hypoglycemia
# 62              29           36     hypoglycemia
# 167             48           56              NaN

# %%
patients_df
# Out:
#      patient_id assigned_sex given_name      surname  \
# 0             1       female        Zoe      Wellish
# 1             2       female     Pamela         Hill
# 2             3         male        Jae       Debord
# 3             4         male       Liêm         Phan
# 4             5         male        Tim      Neudorf
# ..          ...          ...        ...          ...
# 498         499         male    Mustafa    Lindström
# 499         500         male      Ruman      Bisliev
# 500         501       female      Jinke    de Keizer
# 501         502       female    Chidalu  Onyekaozulu
# 502         503         male        Pat      Gersten
#
#                        address               city       state zip_code  \
# 0         576 Brown Bear Drive  Rancho California  California    92390
# 1    2370 University Hill Road          Armstrong    Illinois    61812
# 2        1493 Poling Farm Road               York    Nebraska    68467
# ...

# %%
#code
treatment_dfs=treatment_dfs.drop_duplicates(keep='first',subset=['given_name','surname'])

# %%
#code
state_mapping = {
    'NJ': 'New Jersey',
    'AL': 'Alabama',
    'NV': 'Nevada',
    'CA': 'California',
    'MO': 'Missouri',
    'MI': 'Michigan',
    'TN': 'Tennessee',
    'VA': 'Virginia',
    'OK': 'Oklahoma',
    'GA': 'Georgia',
    'MT': 'Montana',
    'MA': 'Massachusetts',
    'NY': 'New York',
    'NM': 'New Mexico',
    'IL': 'Illinois',
    'LA': 'Louisiana',
    'PA': 'Pennsylvania',
    'CO': 'Colorado',
    'ME': 'Maine',
    'WI': 'Wisconsin',
    'SD': 'South Dakota',
    'MN': 'Minnesota',
    'FL': 'Florida',
    'WY': 'Wyoming',
    'OH': 'Ohio',
    'IA': 'Iowa',
    'NC': 'North Carolina',
    'IN': 'Indiana',
    'CT': 'Connecticut',
    'KY': 'Kentucky',
    'DE': 'Delaware',
    'MD': 'Maryland',
    'AZ': 'Arizona',
    'TX': 'Texas',
    'NE': 'Nebraska',
    'AK': 'Alaska',
    'ND': 'North Dakota',
    'KS': 'Kansas',
    'MS': 'Mississippi',
    'WA': 'Washington',
    'SC': 'South Carolina',
    'WV': 'West Virginia',
    'RI': 'Rhode Island',
    'NH': 'New Hampshire',
    'OR': 'Oregon',
    'no data': 'Unknown',  # Example: Replace 'no data' with appropriate value
    'VT': 'Vermont',
    'ID': 'Idaho',
    'DC': 'District of Columbia',
    'AR': 'Arkansas'
}

# %%
#code
patients_df['state']=patients_df['state'].map(state_mapping)
# Out:
# <ipython-input-453-077fbe2b5934>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   patients_df['state']=patients_df['state'].map(state_mapping)

# %%
#test
patients_df.state.unique()
# Out:
# array([nan, 'New Jersey', 'Alabama', 'Nevada', 'California', 'Missouri',
#        'Michigan', 'Tennessee', 'Virginia', 'Oklahoma', 'Georgia',
#        'Montana', 'Massachusetts', 'New York', 'New Mexico', 'Illinois',
#        'Louisiana', 'Pennsylvania', 'Colorado', 'Maine', 'Wisconsin',
#        'South Dakota', 'Minnesota', 'Florida', 'Wyoming', 'Ohio', 'Iowa',
#        'North Carolina', 'Indiana', 'Connecticut', 'Kentucky', 'Delaware',
#        'Maryland', 'Arizona', 'Texas', 'Nebraska', 'Alaska',
#        'North Dakota', 'Kansas', 'Mississippi', 'Washington',
#        'South Carolina', 'West Virginia', 'Rhode Island', 'New Hampshire',
#        'Oregon', 'Unknown', 'Vermont', 'Idaho', 'District of Columbia',
#        'Arkansas'], dtype=object)
