# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
cs_df=pd.read_csv('https://raw.githubusercontent.com/derekbanas/seaborn/master/ComputerSales.csv')
cs_df
# Out:
#      Sale ID         Contact Sex  Age State     Product ID Product Type  \
# 0          1     Paul Thomas   M   43    OH      M01-F0024      Desktop
# 1          2     Margo Simms   F   37    WV      GT13-0024      Desktop
# 2          3       Sam Stine   M   26    PA          I3670      Desktop
# 3          4      Moe Eggert   M   35    PA          I3593       Laptop
# 4          5     Jessica Elk   F   55    PA         15M-ED       Laptop
# ..       ...             ...  ..  ...   ...            ...          ...
# 97        98  Michelle Samms   F   46    NY    17-BY3613DX       Laptop
# 98        99    Mick Roberts   M   23    PA          BB980      Desktop
# 99       100     Ed Klondike   M   52    OH   15M-ED0023DX       Laptop
# 100      101      Moe Eggert   M   35    PA     GMA4000BST      Desktop
# 101      102     Jessica Elk   F   55    PA  AN515-55-53AG       Tablet
#
#      Sale Price  Profit     Lead     Month  Year
# 0        479.99  143.39  Website   January  2018
# ...

# %%
fs_df=pd.read_excel('https://raw.githubusercontent.com/derekbanas/seaborn/master/Financial%20Sample.xlsx')
fs_df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
car_crash=sns.load_dataset('car_crashes')
car_crash
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
tips_df=sns.load_dataset('tips')
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #.dist plot

# %%
# Provides a way to look at a univariate distribution. A
# univeriate distribution provides a distribution for one variable
# Kernal Density Estimation with a Histogram is provided
# kde=False removes the KDE
# Bins define how many buckets to divide the data up into between intervals
sns.distplot(car_crash['not_distracted'],bins=20,kde=True)

# %% [markdown]
# # joint plot

# %%
# Jointplot compares 2 distributions and plots a scatter plot by default
# As we can see as people tend to speed they also tend to drink & drive
# With kind you can create a regression line with kind='reg'
# You can create a 2D KDE with kind='kde'
# Kernal Density Estimation estimates the distribution of data
# You can create a hexagon distribution with kind='hex'
plt.figure(figsize=(6,6))
sns.jointplot(x='speeding',y='alcohol',data=car_crash,kind='hex')
plt.show()

# %% [markdown]
# #kdeplot

# %%
sns.kdeplot(car_crash['alcohol'])

# %% [markdown]
# #pairplot

# %%
tips_df=sns.load_dataset('tips')
tips_df
sns.pairplot(data=tips_df,hue='sex',palette='viridis')

# %% [markdown]
# > # styling

# %%
plt.figure(figsize=(6,6))
sns.set_style('darkgrid')
sns.set_context('paper',font_scale=1.4)
sns.despine(left=False, bottom=False)
sns.jointplot(data=tips_df,x='tip',y='total_bill',hue='sex',palette='viridis')

# %%
import numpy as np

# %% [markdown]
# #barplot

# %%
sns.barplot(x='sex',y='total_bill',data=tips_df,estimator=np.mean)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# count plot

# %%
sns.countplot(x='sex',hue='smoker',data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# #.boxplot

# %%
sns.boxplot(x='sex',y='total_bill',hue='smoker',data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# #.violin plot

# %%
sns.violinplot(x='sex',y='total_bill',hue='smoker',data=tips_df,split=True)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# stripplot

# %%
sns.stripplot(x='sex',y='total_bill',data=tips_df,jitter=True,hue='smoker',dodge=True)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
#sns.violinplot(x='day',y='total_bill',data=tips_df)
sns.swarmplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.set_context('paper',font_scale=1.4)
sns.swarmplot(x='day',y='total_bill',data=tips_df,hue='smoker',palette='spring')
plt.legend(loc=2,bbox_to_anchor=(1,1))

# %% [markdown]
# #heatmap

# %%
car_mx=car_crash.corr()
# Out:
# <ipython-input-16-4da06d0e8f85>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car_mx=car_crash.corr()

# %%
car_crash
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.set_context('paper',font_scale=1.4)
sns.heatmap(car_mx,annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
# flights=sns.load_dataset('flights')
# flights
flights = sns.load_dataset("flights").pivot("month", "year", "passengers")
# Out:
# <ipython-input-19-629d902c141b>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = sns.load_dataset("flights").pivot("month", "year", "passengers")

# %%
plt.figure(figsize=(8,5))
sns.set_style('darkgrid')
sns.set_context('paper',font_scale=1.4)

sns.heatmap(flights,fmt='d',annot=True,linewidths=0.5,cmap='Purples',annot_kws={"fontsize":13})
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
species=iris.pop('species')

# %% [markdown]
# #clustermap

# %%
plt.figure(figsize=(8,4))
sns.set_style('darkgrid')
sns.set_context('paper',font_scale=1.4)
sns.clustermap(iris)

# %%
sns.clustermap(flights,cmap='Blues',standard_scale=1)

# %%
iris=sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #pairgrid

# %%
# iris_g=sns.PairGrid(iris,hue='species')
#iris_g.map_offdiag(plt.scatter)
# iris_g.map_diag(plt.hist)
# iris_g.map_lower(sns.kdeplot)
# iris_g.map_upper(plt.scatter)
iris_g=sns.PairGrid(iris,hue='species',x_vars=['sepal_length','sepal_width'],y_vars=['petal_length','petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# #facetgrid

# %%
plt.figure(figsize=(18,12))
tips_fc=sns.FacetGrid(tips_df,col='time',row='smoker')
tips_fc.map(plt.scatter,'total_bill','tip')

# %%
tips_fc=sns.FacetGrid(tips_df,col='time' ,hue='smoker', height=4, aspect=1.4,col_order=['Dinner','Lunch'],palette='Set1')
tips_fc.map(plt.scatter, 'total_bill', 'tip', edgecolor='w')

# %%
kws=dict(s=50,linewidth=.5,edgecolor='w')
tips_fg=sns.FacetGrid(tips_df,col='sex',hue='smoker',hue_order=['Yes','No'],height=4,aspect=1,hue_kws=dict(marker=['*','^']))
tips_fg.map(plt.scatter,'total_bill','tip')

# %%
att_df=sns.load_dataset('attention')
att_fg=sns.FacetGrid(att_df,col='subject',col_wrap=5,height=1.5)
att_fg.map(plt.plot,'solutions','score',marker='>')

# %% [markdown]
# #regretionplot

# %%
plt.figure(figsize=(8,4))
sns.set_style('whitegrid')
sns.set_context('paper',font_scale=1.4)
sns.lmplot(data=tips_df,x='total_bill',y='tip',hue='sex',markers=['o','^'],scatter_kws={'s':100,'linewidth':0.5,'edgecolor':'w'})

# %%
sns.lmplot(data=tips_df,x='total_bill',y='tip',col='sex',row ='smoker',scatter_kws={'s':100,'linewidth':0.5,'edgecolor':'w'})
